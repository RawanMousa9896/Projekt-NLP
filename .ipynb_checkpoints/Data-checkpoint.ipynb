# %%
import pandas as pd
import requests
import time

# %%
# TMDb-API-Schlüssel
api_key = '8fd8f41e872ddd873838d1f0f571e31b'

# Basis-URL für die API-Anfragen
base_url = 'https://api.themoviedb.org/3/discover/movie'

# Parameter für die Anfrage
params = {
    'api_key': api_key,
    'language': 'en-US',
    'sort_by': 'popularity.desc',
    'include_adult': 'false',
    'include_video': 'false',
    'page': 1,
    'primary_release_date.gte': '2015-01-01',
    'primary_release_date.lte': '2023-12-31',
    'with_original_language': None
}

# Funktion, um Filme von einer bestimmten Seite abzurufen
def get_movies(page):
    params['page'] = page
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        return response.json().get('results', [])
    else:
        print(f"Fehler beim Abrufen der Seite {page}: {response.status_code}")
        return []

# Filmdaten speichern
movies = []

# Erhöhe die Anzahl der Seiten
total_pages = 100  # Anzahl der Seiten, die man abrufen möchte

# Erweiterte Sprachenliste
languages = {
    'hi': 'Indisch',
    'en': 'Amerikanisch',
    'de': 'Deutsch',
    'fr': 'Französisch',
    'es': 'Spanisch',
    'it': 'Italienisch'
}

# Filme für jede Sprache sammeln
for lang_code, lang_name in languages.items():
    params['with_original_language'] = lang_code
    for page in range(1, total_pages + 1):
        print(f"Verarbeite Seite {page} für Sprache: {lang_name}")
        movies_on_page = get_movies(page)
        for movie in movies_on_page:
            movies.append({
                'title': movie.get('title'),
                'release_year': movie.get('release_date', '')[:4],
                'language': lang_name,
                'overview': movie.get('overview', ''),
                'vote_average': movie.get('vote_average', 0),
                'vote_count': movie.get('vote_count', 0),
                'popularity': movie.get('popularity', 0),
            })
        time.sleep(0.2)

# Speichern in einer CSV-Datei
df = pd.DataFrame(movies)
df.to_csv('movies_2015_2023.csv', index=False)
print(f"Gesamtanzahl der Filme: {len(df)}")
# Out:
# Verarbeite Seite 1 für Sprache: Indisch
# Verarbeite Seite 2 für Sprache: Indisch
# Verarbeite Seite 3 für Sprache: Indisch
# Verarbeite Seite 4 für Sprache: Indisch
# Verarbeite Seite 5 für Sprache: Indisch
# Verarbeite Seite 6 für Sprache: Indisch
# Verarbeite Seite 7 für Sprache: Indisch
# Verarbeite Seite 8 für Sprache: Indisch
# Verarbeite Seite 9 für Sprache: Indisch
# Verarbeite Seite 10 für Sprache: Indisch
# Verarbeite Seite 11 für Sprache: Indisch
# Verarbeite Seite 12 für Sprache: Indisch
# Verarbeite Seite 13 für Sprache: Indisch
# Verarbeite Seite 14 für Sprache: Indisch
# Verarbeite Seite 15 für Sprache: Indisch
# Verarbeite Seite 16 für Sprache: Indisch
# Verarbeite Seite 17 für Sprache: Indisch
# Verarbeite Seite 18 für Sprache: Indisch
# Verarbeite Seite 19 für Sprache: Indisch
# Verarbeite Seite 20 für Sprache: Indisch
# Verarbeite Seite 21 für Sprache: Indisch
# Verarbeite Seite 22 für Sprache: Indisch
# Verarbeite Seite 23 für Sprache: Indisch
# Verarbeite Seite 24 für Sprache: Indisch
# Verarbeite Seite 25 für Sprache: Indisch
# Verarbeite Seite 26 für Sprache: Indisch
# Verarbeite Seite 27 für Sprache: Indisch
# Verarbeite Seite 28 für Sprache: Indisch
# Verarbeite Seite 29 für Sprache: Indisch
# Verarbeite Seite 30 für Sprache: Indisch
# Verarbeite Seite 31 für Sprache: Indisch
# Verarbeite Seite 32 für Sprache: Indisch
# Verarbeite Seite 33 für Sprache: Indisch
# Verarbeite Seite 34 für Sprache: Indisch
# Verarbeite Seite 35 für Sprache: Indisch
# Verarbeite Seite 36 für Sprache: Indisch
# Verarbeite Seite 37 für Sprache: Indisch
# Verarbeite Seite 38 für Sprache: Indisch
# Verarbeite Seite 39 für Sprache: Indisch
# Verarbeite Seite 40 für Sprache: Indisch
# Verarbeite Seite 41 für Sprache: Indisch
# Verarbeite Seite 42 für Sprache: Indisch
# Verarbeite Seite 43 für Sprache: Indisch
# Verarbeite Seite 44 für Sprache: Indisch
# Verarbeite Seite 45 für Sprache: Indisch
# Verarbeite Seite 46 für Sprache: Indisch
# Verarbeite Seite 47 für Sprache: Indisch
# Verarbeite Seite 48 für Sprache: Indisch
# Verarbeite Seite 49 für Sprache: Indisch
# Verarbeite Seite 50 für Sprache: Indisch
# Verarbeite Seite 1 für Sprache: Amerikanisch
# Verarbeite Seite 2 für Sprache: Amerikanisch
# Verarbeite Seite 3 für Sprache: Amerikanisch
# Verarbeite Seite 4 für Sprache: Amerikanisch
# Verarbeite Seite 5 für Sprache: Amerikanisch
# Verarbeite Seite 6 für Sprache: Amerikanisch
# Verarbeite Seite 7 für Sprache: Amerikanisch
# Verarbeite Seite 8 für Sprache: Amerikanisch
# Verarbeite Seite 9 für Sprache: Amerikanisch
# Verarbeite Seite 10 für Sprache: Amerikanisch
# Verarbeite Seite 11 für Sprache: Amerikanisch
# Verarbeite Seite 12 für Sprache: Amerikanisch
# Verarbeite Seite 13 für Sprache: Amerikanisch
# Verarbeite Seite 14 für Sprache: Amerikanisch
# Verarbeite Seite 15 für Sprache: Amerikanisch
# Verarbeite Seite 16 für Sprache: Amerikanisch
# Verarbeite Seite 17 für Sprache: Amerikanisch
# Verarbeite Seite 18 für Sprache: Amerikanisch
# Verarbeite Seite 19 für Sprache: Amerikanisch
# Verarbeite Seite 20 für Sprache: Amerikanisch
# Verarbeite Seite 21 für Sprache: Amerikanisch
# Verarbeite Seite 22 für Sprache: Amerikanisch
# Verarbeite Seite 23 für Sprache: Amerikanisch
# Verarbeite Seite 24 für Sprache: Amerikanisch
# Verarbeite Seite 25 für Sprache: Amerikanisch
# Verarbeite Seite 26 für Sprache: Amerikanisch
# Verarbeite Seite 27 für Sprache: Amerikanisch
# Verarbeite Seite 28 für Sprache: Amerikanisch
# Verarbeite Seite 29 für Sprache: Amerikanisch
# Verarbeite Seite 30 für Sprache: Amerikanisch
# Verarbeite Seite 31 für Sprache: Amerikanisch
# Verarbeite Seite 32 für Sprache: Amerikanisch
# Verarbeite Seite 33 für Sprache: Amerikanisch
# Verarbeite Seite 34 für Sprache: Amerikanisch
# Verarbeite Seite 35 für Sprache: Amerikanisch
# Verarbeite Seite 36 für Sprache: Amerikanisch
# Verarbeite Seite 37 für Sprache: Amerikanisch
# Verarbeite Seite 38 für Sprache: Amerikanisch
# Verarbeite Seite 39 für Sprache: Amerikanisch
# Verarbeite Seite 40 für Sprache: Amerikanisch
# Verarbeite Seite 41 für Sprache: Amerikanisch
# Verarbeite Seite 42 für Sprache: Amerikanisch
# Verarbeite Seite 43 für Sprache: Amerikanisch
# Verarbeite Seite 44 für Sprache: Amerikanisch
# Verarbeite Seite 45 für Sprache: Amerikanisch
# Verarbeite Seite 46 für Sprache: Amerikanisch
# Verarbeite Seite 47 für Sprache: Amerikanisch
# Verarbeite Seite 48 für Sprache: Amerikanisch
# Verarbeite Seite 49 für Sprache: Amerikanisch
# Verarbeite Seite 50 für Sprache: Amerikanisch
# Verarbeite Seite 1 für Sprache: Deutsch
# Verarbeite Seite 2 für Sprache: Deutsch
# Verarbeite Seite 3 für Sprache: Deutsch
# Verarbeite Seite 4 für Sprache: Deutsch
# Verarbeite Seite 5 für Sprache: Deutsch
# Verarbeite Seite 6 für Sprache: Deutsch
# Verarbeite Seite 7 für Sprache: Deutsch
# Verarbeite Seite 8 für Sprache: Deutsch
# Verarbeite Seite 9 für Sprache: Deutsch
# Verarbeite Seite 10 für Sprache: Deutsch
# Verarbeite Seite 11 für Sprache: Deutsch
# Verarbeite Seite 12 für Sprache: Deutsch
# Verarbeite Seite 13 für Sprache: Deutsch
# Verarbeite Seite 14 für Sprache: Deutsch
# Verarbeite Seite 15 für Sprache: Deutsch
# Verarbeite Seite 16 für Sprache: Deutsch
# Verarbeite Seite 17 für Sprache: Deutsch
# Verarbeite Seite 18 für Sprache: Deutsch
# Verarbeite Seite 19 für Sprache: Deutsch
# Verarbeite Seite 20 für Sprache: Deutsch
# Verarbeite Seite 21 für Sprache: Deutsch
# Verarbeite Seite 22 für Sprache: Deutsch
# Verarbeite Seite 23 für Sprache: Deutsch
# Verarbeite Seite 24 für Sprache: Deutsch
# Verarbeite Seite 25 für Sprache: Deutsch
# Verarbeite Seite 26 für Sprache: Deutsch
# Verarbeite Seite 27 für Sprache: Deutsch
# Verarbeite Seite 28 für Sprache: Deutsch
# Verarbeite Seite 29 für Sprache: Deutsch
# Verarbeite Seite 30 für Sprache: Deutsch
# Verarbeite Seite 31 für Sprache: Deutsch
# Verarbeite Seite 32 für Sprache: Deutsch
# Verarbeite Seite 33 für Sprache: Deutsch
# Verarbeite Seite 34 für Sprache: Deutsch
# Verarbeite Seite 35 für Sprache: Deutsch
# Verarbeite Seite 36 für Sprache: Deutsch
# Verarbeite Seite 37 für Sprache: Deutsch
# Verarbeite Seite 38 für Sprache: Deutsch
# Verarbeite Seite 39 für Sprache: Deutsch
# Verarbeite Seite 40 für Sprache: Deutsch
# Verarbeite Seite 41 für Sprache: Deutsch
# Verarbeite Seite 42 für Sprache: Deutsch
# Verarbeite Seite 43 für Sprache: Deutsch
# Verarbeite Seite 44 für Sprache: Deutsch
# Verarbeite Seite 45 für Sprache: Deutsch
# Verarbeite Seite 46 für Sprache: Deutsch
# Verarbeite Seite 47 für Sprache: Deutsch
# Verarbeite Seite 48 für Sprache: Deutsch
# Verarbeite Seite 49 für Sprache: Deutsch
# Verarbeite Seite 50 für Sprache: Deutsch
# Daten erfolgreich in movies_2015_2023.csv gespeichert.

# %%
# CSV-Datei in pandas DataFrame laden
df = pd.read_csv('movies_2015_2023.csv')

# Zeige die ersten Zeilen an (optional)
print(df.head())

# Anzahl der Filme (Zeilen) ermitteln
print(f"Die Gesamtanzahl der Filme: {len(df)}")
# Out:
#                       title  release_year language  \
# 0                   Tumbbad          2018  Indisch
# 1                    Attack          2022  Indisch
# 2  Uri: The Surgical Strike          2019  Indisch
# 3                     Jawan          2023  Indisch
# 4                    Animal          2023  Indisch
#
#                                             overview  vote_average  \
# 0  India, 1918. On the outskirts of Tumbbad, a cu...         7.500
# 1  With the Parliament under siege, India’s first...         6.739
# 2  Following the roguish terrorist attacks at Uri...         7.069
# 3  An emotional journey of a prison warden, drive...         7.200
# 4  The hardened son of a powerful industrialist r...         6.540
#
#    vote_count  popularity
# 0         240      83.749
# 1         203      70.088
# 2         419      56.646
# 3         241      55.272
# 4         101      37.689
# Die Gesamtanzahl der Filme: 3000
